# %%
from optimums import optimums, times
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
timesValues = []
for val in times[2].values():
    timesValues.append(val)
nb = np.array([10, 15, 17, 20, 21, 22, 23, 24])
t = np.array(timesValues)

# %%
plt.plot(nb, t)
plt.text(10, 200, r'Partition en 2 classes', fontsize=15, color = "red")
plt.title('Temps en fonction du nombre de sommets', fontsize=20)
plt.xlabel('Nombre de sommets')
plt.ylabel('Temps [sec]')
plt.savefig('graphImplicitSearch.png')
